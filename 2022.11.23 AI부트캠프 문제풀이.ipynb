# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df1 = pd.read_csv('C:/Users/User/Desktop/코딩/JAY 연습장/eximg/titanic_train.csv')
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
from IPython.display import Image

# %% [markdown]
# - subplots을 이용하여 주요 category성 컬럼의 건수를 시각화 하기

# %%
Image('C:/Users/User/Desktop/코딩/JAY 연습장/eximg/seaborn1.png')

# %%
bins = [0, 18, 25, 35, 60, 80]
group_names = ['Childeren', 'Youth', 'YoungAdult', 'MiddleAged', 'Senior']
df1['Age_cat']= pd.cut(df1['Age'], bins, labels=group_names)

# %%
df1["Age_cat"].value_counts().index
# Out:
# CategoricalIndex(['YoungAdult', 'MiddleAged', 'Youth', 'Childeren', 'Senior'], categories=['Childeren', 'Youth', 'YoungAdult', 'MiddleAged', 'Senior'], ordered=True, dtype='category')

# %%
cat_columns = ["Survived", "Pclass", "Sex", "Embarked", "Age_cat"]

figrue, axes = plt.subplots(nrows=1, ncols=len(cat_columns), figsize=(22, 4))

for index, column in enumerate(cat_columns):
    sns.countplot(data=df1, x=column, ax=axes[index] )
    if (index == 4):
        print(axes[4].get_xticklabels())
        axes[4].set_xticklabels(axes[4].get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'Childeren'), Text(1, 0, 'Youth'), Text(2, 0, 'YoungAdult'), Text(3, 0, 'MiddleAged'), Text(4, 0, 'Senior')]

# %% [markdown]
# - subplots을 이용하여 주요 category성 컬럼별로 컬럼값에 따른 생존율 시각화 하기

# %%
Image('C:/Users/User/Desktop/코딩/JAY 연습장/eximg/seaborn2.png')

# %%
cat_columns = ["Pclass", "Sex", "Embarked", "Age_cat"]

figrue, axes = plt.subplots(nrows=1, ncols=len(cat_columns), figsize=(22, 4))

for index, column in enumerate(cat_columns):
    sns.barplot(data=df1, x=column, y="Survived", ax=axes[index])
