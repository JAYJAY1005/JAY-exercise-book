# %% [markdown]
# ## Data  개요
# **적포도주 및 백포도주 샘플의 물리화학적 특성 및 품질 등급**
# - UCI 머신러닝 저장소에 공개 : [dataset](https://archive.ics.uci.edu/ml/datasets/Wine+Quality)
# - 포르투갈 "Vinho Verde" 와인의 레드 및 화이트 변종 샘플에 대한 정보를 제공
# - 각 와인 샘플은 와인 전문가에 의해 품질 평가를 받았고 화학적 테스트를 거쳤음
# - 개인 정보 보호 및 물류 문제로 인해 포도 유형, 와인 브랜드, 와인 판매 가격 등에 대한 데이터가 없음

# %% [markdown]
# ```
#    Input variables (based on physicochemical tests):
#    1 - fixed acidity (고정된 산도)
#    2 - volatile acidity (휘발성 산도)
#    3 - citric acid (구연산)
#    4 - residual sugar (잔여 설탕)
#    5 - chlorides (염화물)
#    6 - free sulfur dioxide (유리 이산화황)
#    7 - total sulfur dioxide (총 이산화황)
#    8 - density (밀도)
#    9 - pH (산도)
#    10 - sulphates (황산염)
#    11 - alcohol (알코올)
#
#    Output variable (based on sensory data):
#    12 - quality (품질) (score between 0 and 10)
# ```

# %% [markdown]
# ## Step 1: 질문하기 (Ask questions)
# 데이터가 주어진 상태에서 질문을 할 수도 있고, 질문에 답할 수 있는 데이터를 수집할 수도 있다.

# %% [markdown]
# **질문 예시**
# - 와인의 품질을 예측하는 데 가장 중요한 화학적 특성은 무엇일까?
# - 어떤 유형(white, red)의 와인이 더 좋은 평가를 받을까?
# - 알코올 도수가 높은 와인이 더 좋은 평가를 받을까?
# - 더 달콤한 와인이 더 나은 평가를 받을까?
# - 어느 정도의 산도가 와인 품질에 영향을 미칠까?

# %% [markdown]
# ## Step 2: 데이터 랭글링 (Wrangle data)
# - 데이터 랭글링 : 원자료(raw data)를 보다 쉽게 접근하고 분석할 수 있도록 데이터를 정리하고 통합하는 과정
# (참고. 위키피디아)
# - 세부적으로는 데이터의 수집(gather), 평가(assess), 정제(clean) 작업으로 나눌 수 있다.

# %% [markdown]
# ### 2.1 수집(gather)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px

# %%
red = pd.read_csv('C:/Users/User/Desktop/코딩/JAY 연습장/eximg/winequality-red.csv',sep=';')
red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
white = pd.read_csv('C:/Users/User/Desktop/코딩/JAY 연습장/eximg/winequality-white.csv',sep=';')
white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %% [markdown]
# ### 2.2 평가(assess)

# %% [markdown]
# **샘플의 개수**, **컬럼의 개수**

# %%
red.shape, white.shape # 샘플과 컬럼 갯수 확인은 shape로 !!!
# Out:
# ((1599, 13), (4898, 13))

# %%
red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
white.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %% [markdown]
# **누락 데이터 확인**

# %%
red.isnull().sum() # Nan 없음 !!
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
white.isnull().sum() # 여기도 없음 !!
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# **중복 데이터 확인**

# %%
white.duplicated().sum() # 중복 확인하려면 듀플리케이티드에 sum만 붙이면 댐 !!!
# Out:
# 937

# %%
red.duplicated().sum()
# Out:
# 240

# %%
red.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1594    False
# 1595    False
# 1596     True
# 1597    False
# 1598    False
# Length: 1599, dtype: bool

# %%
white.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 4893    False
# 4894    False
# 4895    False
# 4896    False
# 4897    False
# Length: 4898, dtype: bool

# %% [markdown]
# **quality 컬럼(특성)의 고유값과 개수**

# %%
red['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
white['quality'].value_counts()
# Out:
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: quality, dtype: int64

# %%
red['quality'].unique(), red['quality'].nunique() # unique 는 고유값 nunique는 고유값의 수를 알려줌 !!
# Out:
# (array([5, 6, 7, 4, 8, 3], dtype=int64), 6)

# %%
white['quality'].unique(), white['quality'].nunique()
# Out:
# (array([6, 5, 7, 8, 4, 3, 9], dtype=int64), 7)

# %% [markdown]
# **통계 정보 확인**

# %%
red['color'] = 1 # 레드와 화이트를 한표로 합칠건데 분류를 위해 'color'를 추가
white['color'] = 0

# %%
wine = pd.concat([red, white])
wine.reset_index(drop=True, inplace=True)
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  color
# 0         9.4        5      1
# 1         9.8        5      1
# 2         9.8        5      1
# 3         9.8        6      1
# 4         9.4        5      1
# ...       ...      ...    ...
# 6492     11.2        6      0
# 6493      9.6        5      0
# 6494      9.4        6      0
# 6495     12.8        7      0
# 6496     11.8        6      0
#
# [6497 rows x 13 columns]

# %%
wine.describe().T # .T를 쓰면 x,y열을 바꿔서 보여줌
# Out:
#                        count        mean        std      min      25%  \
# fixed acidity         5320.0    7.215179   1.319671  3.80000   6.4000
# volatile acidity      5320.0    0.344130   0.168248  0.08000   0.2300
# citric acid           5320.0    0.318494   0.147157  0.00000   0.2400
# residual sugar        5320.0    5.048477   4.500180  0.60000   1.8000
# chlorides             5320.0    0.056690   0.036863  0.00900   0.0380
# free sulfur dioxide   5320.0   30.036654  17.805045  1.00000  16.0000
# total sulfur dioxide  5320.0  114.109023  56.774223  6.00000  74.0000
# density               5320.0    0.994535   0.002966  0.98711   0.9922
# pH                    5320.0    3.224664   0.160379  2.72000   3.1100
# sulphates             5320.0    0.533357   0.149743  0.22000   0.4300
# alcohol               5320.0   10.549241   1.185933  8.00000   9.5000
# quality               5320.0    5.795677   0.879772  3.00000   5.0000
# color                 5320.0    0.255451   0.436155  0.00000   0.0000
#
#                             50%        75%        max
# fixed acidity           7.00000    7.70000   15.90000
# volatile acidity        0.30000    0.41000    1.58000
# citric acid             0.31000    0.40000    1.66000
# residual sugar          2.70000    7.50000   65.80000
# chlorides               0.04700    0.06600    0.61100
# free sulfur dioxide    28.00000   41.00000  289.00000
# total sulfur dioxide  116.00000  153.25000  440.00000
# density                 0.99465    0.99677    1.03898
# pH                      3.21000    3.33000    4.01000
# sulphates               0.51000    0.60000    2.00000
# alcohol                10.40000   11.40000   14.90000
# quality                 6.00000    6.00000    9.00000
# color                   0.00000    1.00000    1.00000

# %%
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    5320.000000       5320.000000  5320.000000     5320.000000
# mean        7.215179          0.344130     0.318494        5.048477
# std         1.319671          0.168248     0.147157        4.500180
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.240000        1.800000
# 50%         7.000000          0.300000     0.310000        2.700000
# 75%         7.700000          0.410000     0.400000        7.500000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  5320.000000          5320.000000           5320.000000  5320.000000
# mean      0.056690            30.036654            114.109023     0.994535
# std       0.036863            17.805045             56.774223     0.002966
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            16.000000             74.000000     0.992200
# 50%       0.047000            28.000000            116.000000     0.994650
# 75%       0.066000            41.000000            153.250000     0.996770
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality        color
# count  5320.000000  5320.000000  5320.000000  5320.000000  5320.000000
# mean      3.224664     0.533357    10.549241     5.795677     0.255451
# std       0.160379     0.149743     1.185933     0.879772     0.436155
# min       2.720000     0.220000     8.000000     3.000000     0.000000
# 25%       3.110000     0.430000     9.500000     5.000000     0.000000
# 50%       3.210000     0.510000    10.400000     6.000000     0.000000
# 75%       3.330000     0.600000    11.400000     6.000000     1.000000
# max       4.010000     2.000000    14.900000     9.000000     1.000000

# %% [markdown]
# ### 2.3 정제(clean)

# %% [markdown]
# **중복데이터 삭제**

# %%
wine.drop_duplicates(inplace=True)

# %%
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 5               7.4              0.66         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 5                    13.0                  40.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  color
# 0         9.4        5      1
# 1         9.8        5      1
# 2         9.8        5      1
# 3         9.8        6      1
# 5         9.4        5      1
# ...       ...      ...    ...
# 6492     11.2        6      0
# 6493      9.6        5      0
# 6494      9.4        6      0
# 6495     12.8        7      0
# 6496     11.8        6      0
#
# [5320 rows x 13 columns]

# %% [markdown]
# **두 데이터 프레임 합치기**

# %%
wine = pd.concat([red, white])
wine.reset_index(drop=True, inplace=True)
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  color
# 0         9.4        5      1
# 1         9.8        5      1
# 2         9.8        5      1
# 3         9.8        6      1
# 4         9.4        5      1
# ...       ...      ...    ...
# 6492     11.2        6      0
# 6493      9.6        5      0
# 6494      9.4        6      0
# 6495     12.8        7      0
# 6496     11.8        6      0
#
# [6497 rows x 13 columns]

# %% [markdown]
# ## Step 3: 데이터 탐색 (Exploratory Data Analysis)
# 데이터의 패턴을 찾고, 관계를 시각화 하는 작업 등으로 통해 데이터에 대한 직관을 극대화 한다.

# %% [markdown]
# ### 3.1 새로 결합된 데이터 프레임으로 histogram 그리기
# - fixed acidity, total sulfur dioxide, pH, alcohol

# %%
a = ['fixed acidity', 'total sulfur dioxide', 'pH', 'alcohol']

# %%
h = wine[a].hist(bins=20, figsize=(18, 10)) # 이렇게 쉬운데 한참 해맸네 된장 ㅠㅠㅠㅠㅠㅠㅠㅠ

# %%
plt.hist(wine['fixed acidity'],bins=30)
plt.title('fixed acidity')
plt.figure()

# %%
plt.hist(wine['total sulfur dioxide'],bins=30)
plt.title(' total sulfur dioxide')
plt.figure()

# %%
plt.hist(wine['pH'],bins=30)
plt.title('pH')
plt.figure()

# %%
plt.hist(wine['alcohol'],bins=30)
plt.title('alcohol')
plt.figure()

# %% [markdown]
# - Question) 특성 중 오른쪽으로 꼬리가 긴 분포(right skewed distribution)는 어떤것인가?
# - Answer) 'fixed acidity'

# %% [markdown]
# ### 3.2 새로 결합된 데이터 프레임으로 산점도 그리기
# - quality와 아래의 특성들간의 상관관계 파악하기
# - volatile acidity, residual sugar, pH, alcohol

# %%
scatter_col = ['volatile acidity', 'residual sugar', 'pH', 'alcohol', 'quality']

figrue, axes = plt.subplots(nrows=1, ncols=len(scatter_col)-1, figsize=(22, 4))

for index, column in enumerate(scatter_col[:-1]):
    sns.regplot(data=wine[scatter_col], x=column, y='quality', ax=axes[index] )

# %%
plt.scatter(wine['quality'],wine['volatile acidity'],alpha=0.3)
plt.title('volatile acidity')
plt.show()

# %%
plt.scatter(wine['quality'],wine['residual sugar'],alpha=0.3)
plt.title('residual sugar')
plt.show()

# %%
plt.scatter(wine['quality'],wine['pH'],alpha=0.3)
plt.title('pH')
plt.show()

# %%
plt.scatter(wine['quality'],wine['alcohol'],alpha=0.3)
plt.title('alcohol')
plt.show()

# %% [markdown]
# - Question) 품질에 긍정적인 영향을 미칠 가능성이 높은 특성은 어떤 것인가?
# - Answer)

# %% [markdown]
# ## Step 4: 결론 도출 또는 예측 (Draw conclusions or make predictions)

# %% [markdown]
# ###  4.1 어떤 유형(white, red)의 와인이 더 좋은 평가를 받을까?

# %%
a=px.histogram(wine, x='quality', color='color')
a
# Out:
# <div>                            <div id="64ab0f32-0821-4eea-bd6c-08c6997bd8a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64ab0f32-0821-4eea-bd6c-08c6997bd8a7")) {                    Plotly.newPlot(                        "64ab0f32-0821-4eea-bd6c-08c6997bd8a7",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"color=1<br>quality=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1","offsetgroup":"1","orientation":"v","showlegend":true,"x":
7,7,7,6,6,5,6,6,6,6,6,5,6,6,7,6,6,7,6,5,6,6,7,7,6,5,7,6,7,5,5,5,7,6,6,6,6,6,6,6,4,7,5,6,5,6,5,5,6,5,4,6,5,7,5,6,6,6,6,6,7,8,5,7,5,7,6,5,6,6,6,6,6,6,6,6,6,6,6,5,5,5,7,5,6,5,4,6,4,6,4,4,5,5,6,5,6,5,5,6,6,5,5,5,5,5,5,6,6,5,4,5,4,6,6,6,6,8,6,6,5,5,6,6,4,6,7,6,6,6,5,5,6,5,5,5,6,6,4,5,6,6,3,6,6,6,5,5,5,5,4,5,6,5,6,6,6,6,6,6,5,6,5,7,6,5,6,5,6,5,5,6,5,6,6,5,6,5,5,5,5,6,5,5,5,5,6,5,6,5,5,4,6,5,5,6,6,4,5,6,5,3,5,5,6,6,6,5,5,5,5,5,5,5,6,5,5,5,5,6,5,5,7,6,5,6,8,6,7,6,6,7,6,6,5,5,5,7,5,5,5,6,4,6,6,5,5,5,5,6,6,7,6,5,5,5,6,7,6,5,5,6,6,5,5,8,7,7,5,6,6,6,5,7,6,4,6,6,5,7,4,3,5,5,6,5,5,7,7,3,5,4,4,5,4,5,5,5,5,6,6,5,5,7,6,6,6,5,5,5,6,6,3,6,6,5,6,5,6,6,6,6,5,6,5,5,4,5,6,5,6,6,6,6,6,5,6,5,7,6,6,6,5,5,6,7,6,6,7,6,5,5,5,8,5,5,6,5,6,7,5,5,5,5,6,6,5,6,6,6,5,6,6,6,6,6,6,5,6,5,5,7,6,6,6,6,5,6,6,6,6,5,6,5,6],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"color=0<br>quality=%{x}<br>count=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"x":[6,6,6,6,6,6,5,5,5,7,5,7,6,8,6,5,7,8,5,6,6,6,6,6,7,6,6,6,6,5,5,5,6,5,6,6,6,6,6,7,4,5,5,6,7,7,6,6,6,6,6,6,6,6,5,6,5,7,5,8,5,6,5,5,6,7,7,5,5,6,6,5,6,5,6,6,6,5,7,7,7,6,6,7,4,5,5,5,5,6,6,5,6,5,5,5,4,6,6,5,5,5, ...

# %% [markdown]
# - **분석결과** : 레드와인 !!

# %% [markdown]
# ###  4.2 어느 정도의 산도가 와인 품질에 영향을 미칠까?
# - 산도를 4등분하여 (low, medium, medium_high, high ) 어느 단계의 quality의 평균값이 높은지 확인하기

# %%
a=wine['pH'].describe()
a
# Out:
# count    5320.000000
# mean        3.224664
# std         0.160379
# min         2.720000
# 25%         3.110000
# 50%         3.210000
# 75%         3.330000
# max         4.010000
# Name: pH, dtype: float64

# %%
bins = [2.72, 3.11, 3.21, 3.33, 4.01]
labels = ['high', 'medium_high', 'medium', 'low']
wine['acidity_levels'] = pd.cut(wine['pH'], bins=bins, labels =labels)

# %%
wine['acidity_levels'].value_counts()
# Out:
# medium         1391
# high           1331
# medium_high    1330
# low            1267
# Name: acidity_levels, dtype: int64

# %%
wine.groupby('acidity_levels').mean()['quality']
# Out:
# acidity_levels
# high           5.728024
# medium_high    5.766917
# medium         5.852624
# low            5.834254
# Name: quality, dtype: float64

# %%
sns.barplot(data=wine, x='acidity_levels', y='quality')
# Out:
# <AxesSubplot:xlabel='acidity_levels', ylabel='quality'>

# %% [markdown]
# - **분석결과** :

# %% [markdown]
# ###  4.3 더 달콤한 와인이 더 나은 평가를 받을까?

# %%
b = px.histogram(wine, x='quality',y='residual sugar', color='color')
b.show()
# Out:
# <div>                            <div id="d27fd795-2c83-43a7-9f00-06f05f1cdfb0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d